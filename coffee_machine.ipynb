# %% [markdown]
# <a href="https://colab.research.google.com/github/sumantfd23-hash/list_rapo2/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Coffee Machine ")

print("Menu:")
print("1. Espresso - ₹50")
print("2. Latte - ₹70")
print("3. Cappuccino - ₹90")

choice = int(input("Enter your choice (1/2/3): "))

money = int(input("Insert money: ₹"))

if choice == 1:
    if money >= 50:
        print("Here is your Espresso ")
        print("Change:", money - 50)
    else:
        print("Not enough money!")

elif choice == 2:
    if money >= 70:
        print("Here is your Latte ")
        print("Change:", money - 70)
    else:
        print("Not enough money!")

elif choice == 3:
    if money >= 90:
        print("Here is your Cappuccino ")
        print("Change:", money - 90)
    else:
        print("Not enough money!")

else:
    print("Invalid choice!")
# Out:
# Welcome to Coffee Machine
# Menu:
# 1. Espresso - ₹50
# 2. Latte - ₹70
# 3. Cappuccino - ₹90
